# %% [markdown]
# Write a python program that print "Hello, World!"

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# write a python program that takes a user input and prints it

# %%
user_input = input("Enter Name: ")
print(user_input)
# Out:
# 6

# %% [markdown]
# write a python program to check if a number is positive, negative or zero

# %%
number = float(input("Enter a number: "))
if number > 0:
    print("The number is positive.")
elif number < 0:
    print("The number is negative.")
else:
    print("The number is zero.")
# Out:
# The number is positive.

# %% [markdown]
# write a python program to find the largest of three numbers

# %%
num1 = int(input("Enter a number: "))
num2 = int(input("Enter another number: "))
num3 = int(input("Enter a third number: ")) 
if num1 >= num2 and num1 >= num3:
    print(f"{num1} is the largest number.")
elif num2 >= num1 and num2 >= num3:
    print(f"{num2} is the largest number.")
else:
    print(f"{num3} is the largest number.")
# Out:
# 30 is the largest number.

# %% [markdown]
# write a python program to calculate the factorial of a number

# %%
number = int(input("Enter a number: "))
factorial = 1
if number == 0:
    factorial = 1
else:
    for i in range(1, number + 1):
        factorial *= i
print(f"The factorial of {number} is {factorial}.")
# Out:
# The factorial of 5 is 120.

# %% [markdown]
# create a variable of different data types: integer, float, string and boolean. Print their values and types

# %%
num = 10
print(num)
print(type(num))
num = 3.14
print(num)
print(type(num))
num = "Hello"
print(num)
print(type(num))
num = True
print(num)
print(type(num))
# Out:
# 10
# <class 'int'>
# 3.14
# <class 'float'>
# Hello
# <class 'str'>
# True
# <class 'bool'>

# %% [markdown]
# write a python program to swap the values of two variables

# %%
first_num = 10
second_num = 5
first_num, second_num = second_num, first_num
print("First number:", first_num)
print("Second number:", second_num)
# Out:
# First number: 5
# Second number: 10

# %% [markdown]
# write a python program to convert celsius to fahrenheit

# %%
celsius = float(input("Enter temperature in Celsius: "))
fahrenheit = (celsius * 9/5) + 32
print(f"{celsius} degrees Celsius is equal to {fahrenheit} degrees Fahrenheit.")
# Out:
# 6.0 degrees Celsius is equal to 42.8 degrees Fahrenheit.

# %% [markdown]
# write a python program to concatenate two strings

# %%
str1 = "Hello"
str2 = "World"
concatenated = str1 + " " + str2
print(concatenated)
# Out:
# Hello World

# %% [markdown]
# write a python program to check if a variable is of a specific data type

# %%
number = int(input("Enter a number: "))
if isinstance(number, int):
    print("The input is an integer.")
else:
    print("The input is not an integer.")
# Out:
# The input is an integer.

# %% [markdown]
# write a pythin program to perform arithmetic operations: addition, subtraction, multiplication and division

# %%
num1 = 10
num2 = 20
addition = num1 + num2
print(f"The sum of {num1} and {num2} is {addition}.")
subtraction = num1 - num2
print(f"The difference between {num1} and {num2} is {subtraction}.")
multiplication = num1 * num2
print(f"The product of {num1} and {num2} is {multiplication}.")
division = num1 / num2
print(f"The quotient of {num1} divided by {num2} is {division}.")
# Out:
# The sum of 10 and 20 is 30.
# The difference between 10 and 20 is -10.
# The product of 10 and 20 is 200.
# The quotient of 10 divided by 20 is 0.5.

# %% [markdown]
# write a python program to demonstrate comparison operators: equal to, not equal to, greater than, less than

# %%
num1 = 10
num2 = 20
if num1 != num2:
    print(f"{num1} is not equal to {num2}.")
elif num1 > num2:
    print(f"{num1} is greater than {num2}.")
elif num1 < num2:
    print(f"{num1} is less than {num2}.")
else:
    print(f"{num1} is equal to {num2}.")
# Out:
# 10 is not equal to 20.

# %% [markdown]
# write a python program to demonstarate logical operators: and, or, not

# %%
a = True
b = False
print(f"a AND b: {a and b}")
print(f"a OR b: {a or b}")
print(f"NOT a: {not a}")
# Out:
# a AND b: False
# a OR b: True
# NOT a: False

# %% [markdown]
# write a python program to calculate the square of a number

# %%
num1 = int(input("Enter a number: "))
square = num1 ** 2
print(f"The square of {num1} is {square}.")
# Out:
# The square of 5 is 25.

# %% [markdown]
# write a python program to check if a number is even or odd

# %%
number = int(input("Enter a number: "))
if number % 2 == 0:
    print(f"{number} is an even number.")
else:
    print(f"{number} is an odd number.")
# Out:
# 9 is an odd number.

# %% [markdown]
# write a program to find the sum of first n natural numbers

# %%
number = int(input("Enter a number: "))
sum = 0
for i in range(1, number + 1):
    sum += i
print(f"The sum of numbers from 1 to {number} is {sum}.")
# Out:
# The sum of numbers from 1 to 6 is 21.

# %% [markdown]
# write a pythin programe to check if a year is leap year

# %% [markdown]
# write a python program to reverse a string

# %% [markdown]
# write a python program to check if a string is a palindrome

# %% [markdown]
# write a python program to sort a list of numbers in ascending order
