# %% [markdown]
# # Lesson 1.2: Python Basics
# ## Topics Covered:
# - Syntax and Semantics
# - Variables and Data Types
# - Basic Operators (Arithmetic, Comparison, Logical)

# %% [markdown]
# ## 1. Syntax and Semantics
#
# **Question 1:** Write a Python program to print "Hello, World!".

# %%
# Your code here
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# **Question 2:** Write a Python program that takes a user input and prints it.

# %%
# Your code here
num = int(input("Enter a number: "))
print(num)
# Out:
# 10

# %% [markdown]
# **Question 3:** Write a Python program to check if a number is positive, negative, or zero.

# %%
# Your code here
num = int(input("Enter the number: "))
if(num > 0):
    print("The number is Positive")
elif(num < 0):
    print("The number is Negative")
else:
    print("The number is Zero")
# Out:
# The number is Positive

# %% [markdown]
# **Question 4:** Write a Python program to find the largest of three numbers.

# %%
# Your code here
num1 = int(input("Enter the first number: "))
num2 = int(input("Enter the second number: "))
num3 = int(input("Enter the third number: "))
if(num1 >= num2) and (num1 >= num3):
    print(f"{num1} is the largest number.")
elif(num2 >= num1) and (num2 >= num3):
    print(f"{num2} is the largest number.")
else:
    print(f"{num3} is the largest number.")
# Out:
# 30 is the largest number.

# %% [markdown]
# **Question 5:** Write a Python program to calculate the factorial of a number.

# %%
# Your code here
num = int(input("Enter the number: "))
fact = 1
if num == 0:
    print("The factorial of 0 is 1")
elif num < 0:
    print("Factorial does not exist for negative numbers")
else:
    for i in range(1, num + 1):
        fact *= i
    print(f"The factorial of {num} is {fact}")
# Out:
# The factorial of 5 is 120

# %% [markdown]
# ## 2. Variables and Data Types
#
# **Question 6:** Create variables of different data types: integer, float, string, and boolean. Print their values and types.

# %%
# Your code here
num = 10
float_num = 10.5
str_num = "Hello"
bool_num = True
print(f"Integer: {num}, \nFloat: {float_num}, \nString: {str_num}, \nBoolean: {bool_num}")
# Out:
# Integer: 10,
# Float: 10.5,
# String: Hello,
# Boolean: True

# %% [markdown]
# **Question 7:** Write a Python program to swap the values of two variables.

# %%
# Your code here
a = 10
b = 20
print(f"Before swapping: a = {a}, b = {b}")
a, b = b, a
print(f"After swapping: a = {a}, b = {b}")
# Out:
# Before swapping: a = 10, b = 20
# After swapping: a = 20, b = 10

# %% [markdown]
# **Question 8:** Write a Python program to convert Celsius to Fahrenheit.

# %%
# Your code here
temp = float(input("Enter the temperature in Celsius: "))
Fahrenheit = (temp * 9/5) + 32
print(f"The temperature in Fahrenheit is: {Fahrenheit:.2f} °F")
# Out:
# The temperature in Fahrenheit is: 50.00 °F

# %% [markdown]
# **Question 9:** Write a Python program to concatenate two strings.

# %%
# Your code here
str1 = "Abhay"
str2 = "Kumar"
# Concatenation
result = str1 + " " + str2
print(f"Concatenated String: {result}")
# Out:
# Concatenated String: Abhay Kumar

# %% [markdown]
# **Question 10:** Write a Python program to check if a variable is of a specific data type.

# %%
# Your code here
num = 10
print(isinstance(num, int))
# Out:
# True

# %% [markdown]
# ## 3. Basic Operators (Arithmetic, Comparison, Logical)
#
# **Question 11:** Write a Python program to perform arithmetic operations: addition, subtraction, multiplication, and division.

# %%
# Your code here
num1 = int(input("Enter the first number: "))
num2 = int(input("Enter the second number: "))
#addition
sum_result = num1 + num2
print(f"The sum of {num1} and {num2} is: {sum_result}")
#subtraction
sub_result = num1 - num2
print(f"The difference between {num1} and {num2} is: {sub_result}")
#multiplication
mul_result = num1 * num2
print(f"The product of {num1} and {num2} is: {mul_result}")
#division
div_result = num1 / num2
print(f"The division of {num1} by {num2} is: {div_result}")
# Out:
# The sum of 50 and 25 is: 75
# The difference between 50 and 25 is: 25
# The product of 50 and 25 is: 1250
# The division of 50 by 25 is: 2.0

# %% [markdown]
# **Question 12:** Write a Python program to demonstrate comparison operators: equal to, not equal to, greater than, less than.

# %%
# Your code here
num1 = 10
num2 = 20
print(num1 == num2)  
print(num1 != num2)  
print(num1 > num2)   
print(num1 < num2)
# Out:
# False
# True
# False
# True

# %% [markdown]
# **Question 13:** Write a Python program to demonstrate logical operators: and, or, not.

# %%
# Your code here
a = True
b = False
result = a and b
print(f"The result of logical AND between {a} and {b} is: {result}")

result = a or b
print(f"The result of logical OR between {a} and {b} is: {result}")

result = not a
print(f"The result of logical NOT for {a} is: {result}")
# Out:
# The result of logical AND between True and False is: False
# The result of logical OR between True and False is: True
# The result of logical NOT for True is: False

# %% [markdown]
# **Question 14:** Write a Python program to calculate the square of a number.

# %%
# Your code here
num = int(input("Enter a number: "))
result = num ** 2
print(f"The square of {num} is: {result}")
# Out:
# The square of 10 is: 100

# %% [markdown]
# **Question 15:** Write a Python program to check if a number is even or odd.

# %%
# Your code here
num = int(input("Enter a number: "))
if num % 2 == 0:
    print(f"{num} is an Even number.")
else:
    print(f"{num} is an Odd number.")
# Out:
# 10 is an Even number.

# %% [markdown]
# **Question 16:** Write a Python program to find the sum of the first n natural numbers.

# %%
# Your code here
num = int(input("Enter a number: "))
sum = 0
for i in range(1, num + 1):
    sum += i 
    
print(f"The sum of first {num} natural numbers is: {sum}")
# Out:
# The sum of first 10 natural numbers is: 55

# %% [markdown]
# **Question 17:** Write a Python program to check if a year is a leap year.

# %%
# Your code here
year = int(input("Enter a year: "))
if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print(f"{year} is a Leap Year.")
# Out:
# 2024 is a Leap Year.

# %% [markdown]
# **Question 18:** Write a Python program to reverse a string.

# %%
# Your code here
str_input = input("Enter a string: ")
reversed_str = str_input[::-1]
print(f"The reversed string is: {reversed_str}")
# Out:
# The reversed string is: ramuK yahbA

# %% [markdown]
# **Question 19:** Write a Python program to check if a string is a palindrome.

# %%
# Your code here
#write a python program to check if a string is a palindrome or not
str_input = input("Enter a string: ")
forward_str = str_input.lower()
reversed_str = forward_str[::-1]
if forward_str == reversed_str:
    print(f"{str_input} is a Palindrome.")
else:
    print(f"{str_input} is not a Palindrome.")
# Out:
# racecar is a Palindrome.

# %% [markdown]
# **Question 20:** Write a Python program to sort a list of numbers in ascending order.

# %%
# Your code here
num_list = [5, 2, 9, 1, 5, 6]
sorted_list = sorted(num_list) 
print(f"The sorted list in ascending order is: {sorted_list}")
# Out:
# The sorted list in ascending order is: [1, 2, 5, 5, 6, 9]
